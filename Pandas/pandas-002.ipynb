# %%
import pandas as pd

# %%
df = pd.read_csv('melb_data.csv')
df
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# ...

# %%
len(df)
# Out:
# 18396

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method',
#        'SellerG', 'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom',
#        'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea',
#        'Lattitude', 'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
# return rows that their price column is more than 1000000
df_pm1000000 = df[df['Price'] > 1000000]
df_pm1000000
# Out:
#        Unnamed: 0        Suburb          Address  Rooms Type      Price  \
# 0               1    Abbotsford     85 Turner St      2    h  1480000.0
# 1               2    Abbotsford  25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford     5 Charles St      3    h  1465000.0
# 4               6    Abbotsford      55a Park St      4    h  1600000.0
# 6              11    Abbotsford     124 Yarra St      3    h  1876000.0
# ...           ...           ...              ...    ...  ...        ...
# 18390       23539  Williamstown      83 Power St      3    h  1170000.0
# 18392       23541  Williamstown     96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie     17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville       6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville    33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# ...

# %%
# return 5 first rows of df_pm1000000
df_pm1000000.head()
# Out:
#    Unnamed: 0      Suburb          Address  Rooms Type      Price Method  \
# 0           1  Abbotsford     85 Turner St      2    h  1480000.0      S
# 1           2  Abbotsford  25 Bloomburg St      2    h  1035000.0      S
# 2           4  Abbotsford     5 Charles St      3    h  1465000.0     SP
# 4           6  Abbotsford      55a Park St      4    h  1600000.0     VB
# 6          11  Abbotsford     124 Yarra St      3    h  1876000.0      S
#
#   SellerG       Date  Distance  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  Biggin  3/12/2016       2.5  ...       1.0  1.0     202.0           NaN
# 1  Biggin  4/02/2016       2.5  ...       1.0  0.0     156.0          79.0
# 2  Biggin  4/03/2017       2.5  ...       2.0  0.0     134.0         150.0
# 4  Nelson  4/06/2016       2.5  ...       1.0  2.0     120.0         142.0
# 6  Nelson  7/05/2016       2.5  ...       2.0  0.0     245.0         210.0
#
#    YearBuilt  CouncilArea  Lattitude Longtitude             Regionname  \
# ...

# %%
# return 5 last rows of df_pm1000000
df_pm1000000.tail()
# Out:
#        Unnamed: 0        Suburb        Address  Rooms Type      Price Method  \
# 18390       23539  Williamstown    83 Power St      3    h  1170000.0      S
# 18392       23541  Williamstown   96 Verdon St      4    h  2500000.0     PI
# 18393       23544     Yallambie   17 Amaroo Wy      4    h  1100000.0      S
# 18394       23545    Yarraville     6 Agnes St      4    h  1285000.0     SP
# 18395       23546    Yarraville  33 Freeman St      4    h  1050000.0     VB
#
#           SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# 18390       Raine  26/08/2017       6.8  ...       2.0  4.0     436.0
# 18392     Sweeney  26/08/2017       6.8  ...       1.0  5.0     866.0
# 18393  Buckingham  26/08/2017      12.7  ...       3.0  2.0       NaN
# 18394     Village  26/08/2017       6.3  ...       1.0  1.0     362.0
# 18395     Village  26/08/2017       6.3  ...       2.0  2.0       NaN
#
#        BuildingArea  YearBuilt  CouncilArea  Lattitude Longtitude  \
# ...

# %%
# returns the number of non-null (non-missing) values in each column
df_pm1000000.count()
# Out:
# Unnamed: 0       7417
# Suburb           7417
# Address          7417
# Rooms            7417
# Type             7417
# Price            7417
# Method           7417
# SellerG          7417
# Date             7417
# Distance         7417
# Postcode         7417
# Bedroom2         6197
# Bathroom         6195
# Car              6128
# Landsize         5751
# BuildingArea     3166
# YearBuilt        3552
# CouncilArea      5056
# Lattitude        6250
# Longtitude       6250
# Regionname       7417
# Propertycount    7417
# dtype: int64

# %%
df_pm1000000['Car'].count()
# Out:
# 6128

# %%
new_df = df[(df['Price'] > 1000000) & (df['Car'] > 1)]
new_df
# Out:
#        Unnamed: 0        Suburb          Address  Rooms Type      Price  \
# 4               6    Abbotsford      55a Park St      4    h  1600000.0
# 7              14    Abbotsford    98 Charles St      2    h  1636000.0
# 11             18    Abbotsford    10 Valiant St      2    h  1097000.0
# 16             24    Abbotsford  40 Nicholson St      3    h  1350000.0
# 22             30    Abbotsford    16 William St      2    h  1310000.0
# ...           ...           ...              ...    ...  ...        ...
# 18389       23538  Williamstown    77 Merrett Dr      3    h  1031000.0
# 18390       23539  Williamstown      83 Power St      3    h  1170000.0
# 18392       23541  Williamstown     96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie     17 Amaroo Wy      4    h  1100000.0
# 18395       23546    Yarraville    33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# ...

# %%
# It provides summary statistics such as count, mean, standard deviation, minimum, maximum, and various percentiles for each numeric column
df.describe()
# Out:
#          Unnamed: 0         Rooms         Price      Distance      Postcode  \
# count  18396.000000  18396.000000  1.839600e+04  18395.000000  18395.000000
# mean   11826.787073      2.935040  1.056697e+06     10.389986   3107.140147
# std     6800.710448      0.958202  6.419217e+05      6.009050     95.000995
# min        1.000000      1.000000  8.500000e+04      0.000000   3000.000000
# 25%     5936.750000      2.000000  6.330000e+05      6.300000   3046.000000
# 50%    11820.500000      3.000000  8.800000e+05      9.700000   3085.000000
# 75%    17734.250000      3.000000  1.302000e+06     13.300000   3149.000000
# max    23546.000000     12.000000  9.000000e+06     48.100000   3978.000000
#
#            Bedroom2      Bathroom           Car       Landsize  BuildingArea  \
# count  14927.000000  14925.000000  14820.000000   13603.000000   7762.000000
# mean       2.913043      1.538492      1.615520     558.116371    151.220219
# ...

# %%
# in pandas is used to print a concise summary of a DataFrame, including the index dtype and column dtypes, non-null values, and memory usage
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18396 entries, 0 to 18395
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     18396 non-null  int64
#  1   Suburb         18396 non-null  object
#  2   Address        18396 non-null  object
#  3   Rooms          18396 non-null  int64
#  4   Type           18396 non-null  object
#  5   Price          18396 non-null  float64
#  6   Method         18396 non-null  object
#  7   SellerG        18396 non-null  object
#  8   Date           18396 non-null  object
#  9   Distance       18395 non-null  float64
#  10  Postcode       18395 non-null  float64
#  11  Bedroom2       14927 non-null  float64
#  12  Bathroom       14925 non-null  float64
#  13  Car            14820 non-null  float64
#  14  Landsize       13603 non-null  float64
#  15  BuildingArea   7762 non-null   float64
#  16  YearBuilt      8958 non-null   float64
# ...

# %%
new_df.sum(numeric_only=True)
# Out:
# Unnamed: 0       4.828590e+07
# Rooms            1.466800e+04
# Price            6.865107e+09
# Distance         4.123010e+04
# Postcode         1.267730e+07
# Bedroom2         1.452600e+04
# Bathroom         8.110000e+03
# Car              9.532000e+03
# Landsize         2.587574e+06
# BuildingArea     4.832055e+05
# YearBuilt        4.585448e+06
# Lattitude       -1.535034e+05
# Longtitude       5.884055e+05
# Propertycount    2.917027e+07
# dtype: float64

# %%
new_df.mean(numeric_only=True)
# Out:
# Unnamed: 0       1.188722e+04
# Rooms            3.611029e+00
# Price            1.690080e+06
# Distance         1.015020e+01
# Postcode         3.120950e+03
# Bedroom2         3.576071e+00
# Bathroom         1.996553e+00
# Car              2.346627e+00
# Landsize         6.903879e+02
# BuildingArea     2.319758e+02
# YearBuilt        1.960431e+03
# Lattitude       -3.783669e+01
# Longtitude       1.450346e+02
# Propertycount    7.181258e+03
# dtype: float64

# %%
new_df.std(numeric_only=True)
# Out:
# Unnamed: 0         7266.642941
# Rooms                 0.854529
# Price            692594.176382
# Distance              4.378682
# Postcode             59.631501
# Bedroom2              0.895692
# Bathroom              0.792098
# Car                   0.795201
# Landsize           2105.738435
# BuildingArea        988.180836
# YearBuilt            40.400919
# Lattitude             0.068321
# Longtitude            0.081600
# Propertycount      3532.451319
# dtype: float64

# %%
new_df.var(numeric_only=True)
# Out:
# Unnamed: 0       5.280410e+07
# Rooms            7.302206e-01
# Price            4.796867e+11
# Distance         1.917285e+01
# Postcode         3.555916e+03
# Bedroom2         8.022640e-01
# Bathroom         6.274198e-01
# Car              6.323440e-01
# Landsize         4.434134e+06
# BuildingArea     9.765014e+05
# YearBuilt        1.632234e+03
# Lattitude        4.667797e-03
# Longtitude       6.658518e-03
# Propertycount    1.247821e+07
# dtype: float64

# %%
df.head()
# Out:
#    Unnamed: 0      Suburb           Address  Rooms Type      Price Method  \
# 0           1  Abbotsford      85 Turner St      2    h  1480000.0      S
# 1           2  Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2           4  Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3           5  Abbotsford  40 Federation La      3    h   850000.0     PI
# 4           6  Abbotsford       55a Park St      4    h  1600000.0     VB
#
#   SellerG       Date  Distance  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  Biggin  3/12/2016       2.5  ...       1.0  1.0     202.0           NaN
# 1  Biggin  4/02/2016       2.5  ...       1.0  0.0     156.0          79.0
# 2  Biggin  4/03/2017       2.5  ...       2.0  0.0     134.0         150.0
# 3  Biggin  4/03/2017       2.5  ...       2.0  1.0      94.0           NaN
# 4  Nelson  4/06/2016       2.5  ...       1.0  2.0     120.0         142.0
#
# ...

# %%
# add column SA to df
df['SA'] = df['Suburb'] + '-' + df['Address']
df.head()
# Out:
#    Unnamed: 0      Suburb           Address  Rooms Type      Price Method  \
# 0           1  Abbotsford      85 Turner St      2    h  1480000.0      S
# 1           2  Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2           4  Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3           5  Abbotsford  40 Federation La      3    h   850000.0     PI
# 4           6  Abbotsford       55a Park St      4    h  1600000.0     VB
#
#   SellerG       Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  Biggin  3/12/2016       2.5  ...  1.0     202.0           NaN        NaN
# 1  Biggin  4/02/2016       2.5  ...  0.0     156.0          79.0     1900.0
# 2  Biggin  4/03/2017       2.5  ...  0.0     134.0         150.0     1900.0
# 3  Biggin  4/03/2017       2.5  ...  1.0      94.0           NaN        NaN
# 4  Nelson  4/06/2016       2.5  ...  2.0     120.0         142.0     2014.0
#
# ...

# %%
df['CARDis'] = df['Car'] * df['Distance']
df.head()
# Out:
#    Unnamed: 0      Suburb           Address  Rooms Type      Price Method  \
# 0           1  Abbotsford      85 Turner St      2    h  1480000.0      S
# 1           2  Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2           4  Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3           5  Abbotsford  40 Federation La      3    h   850000.0     PI
# 4           6  Abbotsford       55a Park St      4    h  1600000.0     VB
#
#   SellerG       Date  Distance  ...  Landsize  BuildingArea  YearBuilt  \
# 0  Biggin  3/12/2016       2.5  ...     202.0           NaN        NaN
# 1  Biggin  4/02/2016       2.5  ...     156.0          79.0     1900.0
# 2  Biggin  4/03/2017       2.5  ...     134.0         150.0     1900.0
# 3  Biggin  4/03/2017       2.5  ...      94.0           NaN        NaN
# 4  Nelson  4/06/2016       2.5  ...     120.0         142.0     2014.0
#
#    CouncilArea  Lattitude  Longtitude             Regionname Propertycount  \
# ...

# %%
df['Type'].unique()
# Out:
# array(['h', 't', 'u'], dtype=object)

# %%
df['Type'].value_counts()
# Out:
# Type
# h    12095
# u     4296
# t     2005
# Name: count, dtype: int64

# %%
df.groupby('Type')['Price'].min()
# Out:
# Type
# h    131000.0
# t    256000.0
# u     85000.0
# Name: Price, dtype: float64

# %%
df.groupby('Type')['Price'].aggregate(lambda x: x.sum() / len(x))
# Out:
# Type
# h    1.234251e+06
# t    9.240601e+05
# u    6.187154e+05
# Name: Price, dtype: float64

# %%
def f(x):
    return x.sum() / len(x)

# %%
df.groupby('Type')['Price'].aggregate(f)
# Out:
# Type
# h    1.234251e+06
# t    9.240601e+05
# u    6.187154e+05
# Name: Price, dtype: float64
